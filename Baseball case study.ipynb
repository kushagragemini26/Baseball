# %% [markdown]
# Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# -- Output: Number of predicted wins (W)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:\\Users\\kushagra gemini\\Desktop\\baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.nunique().to_frame("Number of unique values")
# Out:
#      Number of unique values
# W                         24
# R                         28
# AB                        29
# H                         29
# 2B                        22
# 3B                        23
# HR                        27
# BB                        29
# SO                        29
# SB                        27
# RA                        30
# ER                        30
# ERA                       30
# CG                         9
# SHO                       12
# SV                        20
# E                         21

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64
#
#
# R
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: count, dtype: int64
#
#
# AB
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: count, dtype: int64
#
#
# H
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: count, dtype: int64
#
#
# 2B
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: count, dtype: int64
#
#
# 3B
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: count, dtype: int64
#
#
# HR
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: count, dtype: int64
#
#
# BB
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: count, dtype: int64
#
#
# SO
# 1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: count, dtype: int64
#
#
# SB
# 69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: count, dtype: int64
#
#
# RA
# 641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: count, dtype: int64
#
#
# ER
# 601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: count, dtype: int64
#
#
# ERA
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: count, dtype: int64
#
#
# CG
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: count, dtype: int64
#
#
# SHO
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: count, dtype: int64
#
#
# SV
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: count, dtype: int64
#
#
# E
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
plt.figure(figsize=(36,20))
sns.heatmap(df.describe(),annot=True,fmt='0.1f',linewidth=1,linecolor='black',cmap='viridis')
plt.xlabel('Figure')
plt.ylabel('Features')
plt.title("Descriptive Graph")
plt.show()

# %%
datamap = sns.countplot(x='W', data=df)
print(df['W'].value_counts())
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64

# %%
datamap = sns.countplot(x='R', data=df)
print(df['R'].value_counts())
# Out:
# R
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: count, dtype: int64

# %%
datamap = sns.countplot(x='CG', data=df)
print(df['CG'].value_counts())
# Out:
# CG
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,15))
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 20)
               
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The data distribution is normally distributed and there doesn't seem to be any skewness

# %%
df.plot.bar(subplots= True,stacked= False, figsize=(20,30))
# Out:
# array([<Axes: title={'center': 'W'}>, <Axes: title={'center': 'R'}>,
#        <Axes: title={'center': 'AB'}>, <Axes: title={'center': 'H'}>,
#        <Axes: title={'center': '2B'}>, <Axes: title={'center': '3B'}>,
#        <Axes: title={'center': 'HR'}>, <Axes: title={'center': 'BB'}>,
#        <Axes: title={'center': 'SO'}>, <Axes: title={'center': 'SB'}>,
#        <Axes: title={'center': 'RA'}>, <Axes: title={'center': 'ER'}>,
#        <Axes: title={'center': 'ERA'}>, <Axes: title={'center': 'CG'}>,
#        <Axes: title={'center': 'SHO'}>, <Axes: title={'center': 'SV'}>,
#        <Axes: title={'center': 'E'}>], dtype=object)

# %% [markdown]
# # Bivariate Analysis

# %%
sns.lineplot(x='R',y='W',data=df)
# Out:
# <Axes: xlabel='R', ylabel='W'>

# %% [markdown]
# It is a positive correlation

# %%
sns.lineplot(x='R',y='W',data=df)
# Out:
# <Axes: xlabel='R', ylabel='W'>

# %%
sns.lineplot(x='AB',y='W',data=df)
# Out:
# <Axes: xlabel='AB', ylabel='W'>

# %%
sns.lineplot(x='H',y='W',data=df)
# Out:
# <Axes: xlabel='H', ylabel='W'>

# %%
sns.lineplot(x='2B',y='W',data=df)
# Out:
# <Axes: xlabel='2B', ylabel='W'>

# %%
plt.figure(figsize=(25,25))
p=1
for i in df.columns:
    if p<=20:    
        plt.subplot(10,3,p) 
        sns.lineplot(x=df[i],y='W',data=df,color='green')
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %%
plt.figure(figsize=(20,30))
p=1
for i in df.columns:
    if p<=20:    
        plt.subplot(10,5,p) 
        sns.regplot(x=df[i],y='W',data=df,color='blue')
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %%
plt.figure(figsize=(20,30))
p=1
for i in df.columns:
    if p<=50:    
        plt.subplot(10,5,p) 
        sns.scatterplot(x=df[i],y='W',data=df,color='orange')
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data=df,palette='Dark2')

# %% [markdown]
# # Outliers

# %%
plt.figure(figsize=(20,35))
p=1
for i in df.columns:
    if p<=20:
        plt.subplot(10,5,p)
        sns.boxplot(df[i],palette="viridis")
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
#  we can see that R,ERA,SHO,SV,E are having some outliers

# %% [markdown]
# # Removing outliers

# %% [markdown]
# Zscore

# %%
from scipy.stats import zscore
out_features=df[['R','ERA','SHO','SV','E']]
z=np.abs(zscore(out_features))  
z
# Out:
#            R       ERA       SHO        SV         E
# 0   0.959398  0.511388  0.787002  1.532753  0.348265
# 1   0.331147  0.238952  0.236737  0.312020  0.540820
# 2   0.274666  0.643801  0.252844  0.664137  1.326125
# 3   1.329231  0.040333  0.513555  0.820689  0.650818
# 4   0.174084  1.496876  0.236737  1.149165  0.540820
# 6   1.856900  0.150677  2.064039  0.677176  0.082858
# 7   0.712585  0.194815  0.252844  0.052325  1.588197
# 8   0.835605  0.489319  0.236737  1.908137  0.237592
# 9   1.497899  0.768604  0.252844  0.365006  0.383386
# 10  1.565212  0.614123  0.513555  0.312020  1.554265
# 11  1.071586  0.864490  0.468029  0.512328  0.641926
# 12  0.454167  0.047943  0.236737  0.436838  0.082858
# 13  0.566355  0.437572  0.236737  0.312020  0.161388
# 14  0.286272  0.393434  0.908147  2.498840  1.810553
# 15  0.768292  2.254827  0.908147  2.084917  0.311562
# 16  0.353585  1.658968  0.468029  1.333006  1.669209
# 17  0.174084  1.327935  2.090856  0.677176  1.203715
# 18  0.588792  0.702398  1.075340  0.365006  1.430810
# 19  0.925355  0.812742  0.787002  1.149165  0.167685
# 20  0.039459  1.173453  0.691583  0.906024  0.348265
# 21  0.488210  0.754146  0.468029  0.221934  0.167685
# 22  1.531169  0.128608  0.236737  1.149165  1.588197
# 23  2.428670  0.989293  0.252844  0.183904  0.167685
# 24  1.239481  1.607220  1.075340  1.149165  1.472959
# 25  0.319542  1.151385  2.090856  0.558509  1.870191
# 26  0.331147  0.533457  1.521828  0.221934  1.454792
# 27  0.869648  0.172746  0.236737  0.183904  0.540820
# 28  0.700980  0.283090  1.381412  0.221934  0.001905
# 29  1.251086  2.379630  2.064039  0.982264  0.237592

# %%
#threshold=3

np.where(b>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
#Now removing the data above Z score and creating a new df

df1=df[(b<3).all(axis=1)]  
df1
# Out:
#       W    R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  724  5575  0.999516  300  42  139  383   973  104  641  601  3.73
# 1    83  696  5467 -0.951092  277  44  156  439  1264   70  700  653  4.07
# 2    81  669  5439  0.132471  303  29  141  533  1157   86  640  584  3.67
# 3    76  622  5533 -0.963763  260  27  136  404  1231   68  701  643  3.98
# 4    74  689  5605  0.683350  289  49  151  455  1259   83  803  746  4.64
# 6    87  764  5567  0.846156  272  19  212  554  1227   63  698  652  4.03
# 7    81  713  5485  0.262491  246  20  217  418  1331   44  693  646  4.05
# 8    80  644  5485  0.643630  278  32  167  436  1310   87  642  604  3.74
# 9    78  748  5640 -0.387670  294  33  161  478  1148   71  753  694  4.31
# 10   88  751  5511 -0.841406  279  32  172  503  1233  101  733  680  4.24
# 11   86  729  5459 -0.436056  278  26  230  486  1392  121  618  572  3.57
# 12   85  661  5417 -0.860008  243  21  176  435  1150   52  675  630  3.94
# 13   76  656  5544  0.158504  262  22  198  478  1336   69  726  677  4.16
# 14   68  694  5600 -0.650379  277  46  146  475  1119   78  729  664  4.14
# 15  100  647  5484 -0.529185  288  39  137  506  1267   69  525  478  2.94
# 16   98  697  5631 -0.916570  292  27  140  461  1322   98  596  532  3.21
# 17   97  689  5491  0.444005  272  30  171  567  1518   95  608  546  3.36
# 18   68  655  5480  0.916473  274  34  145  412  1299   84  737  682  4.28
# 19   64  640  5571 -0.296253  257  27  167  496  1255  134  754  700  4.33
# 20   90  683  5527  0.114905  295  17  177  488  1290   51  613  557  3.43
# 21   83  703  5428 -0.436056  265  13  177  539  1344   57  635  577  3.62
# 22   71  613  5463  0.000121  236  40  120  375  1150  112  678  638  4.02
# 23   67  573  5420 -0.636831  251  18  100  471  1107   69  760  698  4.41
# 24   63  626  5529 -0.901840  272  37  130  387  1274   88  809  749  4.69
# 25   92  667  5385  0.985167  263  26  187  563  1258   59  595  553  3.44
# 26   84  696  5565 -0.026672  288  39  136  457  1159   93  627  597  3.72
# 27   79  720  5649 -0.985126  289  48  154  490  1312  132  713  659  4.04
# 28   74  650  5457 -0.983609  260  36  148  426  1327   82  731  655  4.09
# 29   68  737  5572  0.636645  274  49  186  388  1283   97  844  799  5.04
#
#           CG       SHO        SV         E
# 0   1.230823  4.126886  2.773647  0.538519
# 1   1.230823  5.409438  2.675973  0.538513
# 2   3.232199  4.796085  2.597869  0.538491
# 3   2.587478  4.469464  2.585343  0.538548
# 4   2.587478  5.409438  2.559061  0.538513
# 6   1.601132  2.526999  2.705190  0.538531
# 7   0.000000  4.796085  2.655195  0.538483
# 8   0.744309  5.409438  2.803682  0.538536
# 9   1.601132  4.796085  2.621803  0.538540
# 10  2.161191  4.469464  2.675973  0.538574
# 11  2.161191  5.699204  2.610015  0.538510
# 12  1.230823  5.409438  2.685960  0.538531
# 13  2.386512  5.409438  2.675973  0.538534
# 14  2.161191  6.250589  2.451070  0.538581
# 15  0.744309  6.250589  2.817827  0.538538
# 16  0.000000  5.699204  2.757665  0.538577
# 17  2.386512  7.732300  2.705190  0.538564
# 18  0.744309  3.765654  2.621803  0.538570
# 19  1.230823  4.126886  2.559061  0.538524
# 20  0.744309  5.979274  2.723501  0.538519
# 21  1.903641  5.699204  2.633251  0.538524
# 22  0.000000  5.409438  2.559061  0.538483
# 23  1.601132  4.796085  2.665723  0.538524
# 24  0.744309  3.765654  2.559061  0.538572
# 25  2.386512  7.732300  2.695696  0.538475
# 26  2.587478  7.019416  2.633251  0.538487
# 27  0.744309  5.409438  2.665723  0.538513
# 28  0.744309  3.382202  2.633251  0.538529
# 29  1.903641  2.526999  2.572415  0.538536

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 0.0

# %% [markdown]
# # IQR Method

# %%
#Now lets check with IQR method:
Q1 = out_features.quantile(0.25)
Q3 = out_features.quantile(0.75)

IQR = Q3 - Q1

# Create a mask for values outside the IQR
mask = ((out_features < (Q1 - 1.5 * IQR)) | (out_features > (Q3 + 1.5 * IQR))).any(axis=1)

# Apply the mask to filter the DataFrame
df2 = df[~mask]

# %%
df2
# Out:
#       W    R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  724  5575  0.999516  300  42  139  383   973  104  641  601  3.73
# 1    83  696  5467 -0.951092  277  44  156  439  1264   70  700  653  4.07
# 2    81  669  5439  0.132471  303  29  141  533  1157   86  640  584  3.67
# 3    76  622  5533 -0.963763  260  27  136  404  1231   68  701  643  3.98
# 4    74  689  5605  0.683350  289  49  151  455  1259   83  803  746  4.64
# 7    81  713  5485  0.262491  246  20  217  418  1331   44  693  646  4.05
# 8    80  644  5485  0.643630  278  32  167  436  1310   87  642  604  3.74
# 9    78  748  5640 -0.387670  294  33  161  478  1148   71  753  694  4.31
# 10   88  751  5511 -0.841406  279  32  172  503  1233  101  733  680  4.24
# 11   86  729  5459 -0.436056  278  26  230  486  1392  121  618  572  3.57
# 12   85  661  5417 -0.860008  243  21  176  435  1150   52  675  630  3.94
# 13   76  656  5544  0.158504  262  22  198  478  1336   69  726  677  4.16
# 15  100  647  5484 -0.529185  288  39  137  506  1267   69  525  478  2.94
# 16   98  697  5631 -0.916570  292  27  140  461  1322   98  596  532  3.21
# 18   68  655  5480  0.916473  274  34  145  412  1299   84  737  682  4.28
# 19   64  640  5571 -0.296253  257  27  167  496  1255  134  754  700  4.33
# 20   90  683  5527  0.114905  295  17  177  488  1290   51  613  557  3.43
# 21   83  703  5428 -0.436056  265  13  177  539  1344   57  635  577  3.62
# 22   71  613  5463  0.000121  236  40  120  375  1150  112  678  638  4.02
# 23   67  573  5420 -0.636831  251  18  100  471  1107   69  760  698  4.41
# 24   63  626  5529 -0.901840  272  37  130  387  1274   88  809  749  4.69
# 26   84  696  5565 -0.026672  288  39  136  457  1159   93  627  597  3.72
# 27   79  720  5649 -0.985126  289  48  154  490  1312  132  713  659  4.04
# 28   74  650  5457 -0.983609  260  36  148  426  1327   82  731  655  4.09
#
#           CG       SHO        SV         E
# 0   1.230823  4.126886  2.773647  0.538519
# 1   1.230823  5.409438  2.675973  0.538513
# 2   3.232199  4.796085  2.597869  0.538491
# 3   2.587478  4.469464  2.585343  0.538548
# 4   2.587478  5.409438  2.559061  0.538513
# 7   0.000000  4.796085  2.655195  0.538483
# 8   0.744309  5.409438  2.803682  0.538536
# 9   1.601132  4.796085  2.621803  0.538540
# 10  2.161191  4.469464  2.675973  0.538574
# 11  2.161191  5.699204  2.610015  0.538510
# 12  1.230823  5.409438  2.685960  0.538531
# 13  2.386512  5.409438  2.675973  0.538534
# 15  0.744309  6.250589  2.817827  0.538538
# 16  0.000000  5.699204  2.757665  0.538577
# 18  0.744309  3.765654  2.621803  0.538570
# 19  1.230823  4.126886  2.559061  0.538524
# 20  0.744309  5.979274  2.723501  0.538519
# 21  1.903641  5.699204  2.633251  0.538524
# 22  0.000000  5.409438  2.559061  0.538483
# 23  1.601132  4.796085  2.665723  0.538524
# 24  0.744309  3.765654  2.559061  0.538572
# 26  2.587478  7.019416  2.633251  0.538487
# 27  0.744309  5.409438  2.665723  0.538513
# 28  0.744309  3.382202  2.633251  0.538529

# %%
print("Data Loss Percentage:", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 17.24137931034483

# %% [markdown]
# We can see that the loss of data is more in IQR method so we will use Zscore method

# %%
df=df1

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.292037
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# removing the skewness from CG,SV,E,SHO,H

# %%
import scipy.stats as stats
import numpy as np

# %%
df['CG'],ambda_=stats.yeojohnson(df['CG']) 
df['SV'],ambda_=stats.yeojohnson(df['SV']) 
df['E'],ambda_=stats.yeojohnson(df['E']) 
df['SHO'],ambda_=stats.yeojohnson(df['SHO']) 
df['H']=np.sin(df['H'])

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.304464
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.119340
# SHO   -0.000623
# SV     0.000823
# E      0.000000
# dtype: float64

# %%
plt.figure(figsize=(30,35))
p=1
for i in df.columns:
    if p<=20:
        plt.subplot(10,4,p)
        sns.distplot(df[i],color='b')
        plt.xlabel(i,fontsize=10)
    p+=1
plt.show()

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780  0.113338  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.185556  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000 -0.032608  0.490752  0.445604 -0.064653
# H    0.113338  0.185556 -0.032608  1.000000  0.126602  0.008853  0.296653
# 2B   0.384886  0.469293  0.490752  0.126602  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.008853  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653  0.296653 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850  0.078401  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243  0.000340 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674 -0.089415  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499 -0.056551 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.002921 -0.224993  0.333731 -0.062094
# ERA -0.826952 -0.009122  0.254872  0.010722 -0.248212  0.325883 -0.070756
# CG   0.005189  0.157720 -0.058763  0.151348  0.227739 -0.003793  0.120470
# SHO  0.481581 -0.113706 -0.194210 -0.026162  0.088231 -0.066400 -0.024518
# SV   0.756722  0.083218 -0.147870  0.176875  0.241410 -0.269113  0.106428
# E   -0.079637  0.039914  0.332047 -0.290735  0.152590  0.080440 -0.165781
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.447513  0.156469 -0.169503 -0.823176 -0.815308 -0.826952  0.005189
# R    0.258450  0.081158  0.075323 -0.013858  0.007727 -0.009122  0.157720
# AB  -0.137850 -0.111243  0.373674  0.315499  0.309146  0.254872 -0.058763
# H    0.078401  0.000340 -0.089415 -0.056551  0.002921  0.010722  0.151348
# 2B   0.211243 -0.096772  0.194308 -0.215196 -0.224993 -0.248212  0.227739
# 3B  -0.404852 -0.196586  0.483818  0.312750  0.333731  0.325883 -0.003793
# HR   0.336814  0.479914 -0.166072 -0.092586 -0.062094 -0.070756  0.120470
# BB   1.000000  0.315566 -0.117622 -0.425381 -0.455832 -0.465794  0.446474
# SO   0.315566  1.000000  0.038188 -0.140570 -0.177655 -0.195362 -0.064901
# SB  -0.117622  0.038188  1.000000  0.134315  0.146243  0.128848 -0.040996
# RA  -0.425381 -0.140570  0.134315  1.000000  0.991286  0.986781  0.067842
# ER  -0.455832 -0.177655  0.146243  0.991286  1.000000  0.997261  0.072546
# ERA -0.465794 -0.195362  0.128848  0.986781  0.997261  1.000000  0.079277
# CG   0.446474 -0.064901 -0.040996  0.067842  0.072546  0.079277  1.000000
# SHO  0.440963  0.204642 -0.100040 -0.642740 -0.640156 -0.640499  0.203092
# SV   0.207911  0.125480 -0.195745 -0.626061 -0.604609 -0.619860 -0.299251
# E   -0.056119  0.164813  0.070492  0.231121  0.165644  0.138772 -0.063647
#
#           SHO        SV         E
# W    0.481581  0.756722 -0.079637
# R   -0.113706  0.083218  0.039914
# AB  -0.194210 -0.147870  0.332047
# H   -0.026162  0.176875 -0.290735
# 2B   0.088231  0.241410  0.152590
# 3B  -0.066400 -0.269113  0.080440
# HR  -0.024518  0.106428 -0.165781
# BB   0.440963  0.207911 -0.056119
# SO   0.204642  0.125480  0.164813
# SB  -0.100040 -0.195745  0.070492
# RA  -0.642740 -0.626061  0.231121
# ER  -0.640156 -0.604609  0.165644
# ERA -0.640499 -0.619860  0.138772
# CG   0.203092 -0.299251 -0.063647
# SHO  1.000000  0.196720 -0.206947
# SV   0.196720  1.000000 -0.032255
# E   -0.206947 -0.032255  1.000000

# %%
plt.figure(figsize=(50, 50))
sns.heatmap(df.corr(), annot=True, fmt='0.2f', linewidth=1, linecolor='black', cmap='cividis')
plt.xlabel("Figure")
plt.ylabel("Features name")
plt.title("Descriptive Graph")
plt.show()

# %%
df.corr()['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.756722
# SHO    0.481581
# BB     0.447513
# R      0.390451
# 2B     0.384886
# HR     0.245697
# SO     0.156469
# H      0.113338
# CG     0.005189
# E     -0.079637
# AB    -0.085780
# SB    -0.169503
# 3B    -0.206737
# ER    -0.815308
# RA    -0.823176
# ERA   -0.826952
# Name: W, dtype: float64

# %%
plt.figure(figsize=(25, 18))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar', color='skyblue')
plt.title("Correlation between features and label using bar plot", fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# # Seperating Features and Label

# %%
x=df.drop(['W'],axis=1)
y=df["W"]

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (29, 16)
# Target dimensions: (29,)

# %% [markdown]
# # Feature scaling using standard scalarisation

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.617355  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -1.166579  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253  0.424697  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -1.178846 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  1.264472  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535  1.461829 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345  0.638973 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345  1.211845  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672 -0.433254  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310 -1.051422  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.507820  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.072053 -1.802414 -1.068901  0.506228 -0.569402
# 12 -0.566355  0.390081  0.468016 -0.682763 -0.969865  1.262607  0.230197
# 13  0.286272  1.184926 -0.815805  0.201171  1.406988 -0.525197  0.174411
# 14 -0.768292 -0.461539 -0.646510  0.849390  0.713739 -0.834625  0.750867
# 15  0.353585  1.624929 -1.132048  1.085106 -0.474688 -0.731482 -0.085923
# 16  0.174084 -0.362183  0.925012 -0.093474 -0.177581  0.334324  1.885182
# 17 -0.588792 -0.518313  1.537046  0.024384  0.218561 -0.559578 -0.997094
# 18 -0.925355  0.773310 -0.288455 -0.977408 -0.474688  0.196801  0.564913
# 19  0.039459  0.148789  0.395378  1.261893 -1.465043  0.540609  0.416151
# 20  0.488210 -1.256383 -0.507820 -0.505976 -1.861185  0.540609  1.364512
# 21 -1.531169 -0.759605  0.202751 -2.214917  0.812774 -1.419099 -1.685122
# 22 -2.428670 -1.369933 -0.797577 -1.330982 -1.366007 -2.106716  0.100030
# 23 -1.239481  0.177176 -1.116828 -0.093474  0.515668 -1.075291 -1.461978
# 24 -0.319542 -1.866711  1.604160 -0.623834 -0.573723  0.884418  1.810800
# 25  0.331147  0.688148  0.157696  0.849390  0.713739 -0.869006 -0.160305
# 26  0.869648  1.880415 -1.199024  0.908319  1.605059 -0.250150  0.453341
# 27 -0.700980 -0.844767 -1.197613 -0.800621  0.416632 -0.456435 -0.736760
# 28  1.251086  0.787503  1.202423  0.024384  1.704094  0.850037 -1.443382
#
#           SO        SB        RA        ER       ERA        CG       SHO  \
# 0  -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.285663 -0.786909
# 1   0.121896 -0.585315  0.154638  0.232161  0.238952 -0.285663  0.236894
# 2  -0.925866  0.116458 -0.678397 -0.754153 -0.643801  1.952919 -0.252670
# 3  -0.201246 -0.673037  0.168522  0.089217  0.040333  1.248961 -0.513407
# 4   0.072935 -0.015124  1.584683  1.561540  1.496876  1.248961  0.236894
# 5  -0.240414 -0.892341  0.126870  0.217866  0.150677  0.141896 -2.064651
# 6   0.777970 -1.725697  0.057451  0.132100  0.194815 -1.779464 -0.252670
# 7   0.572335  0.160319 -0.650630 -0.468265 -0.489319 -0.860380  0.236894
# 8  -1.013995 -0.541454  0.890486  0.818231  0.768604  0.141896 -0.252670
# 9  -0.181661  0.774370  0.612808  0.618110  0.614123  0.775509 -0.513407
# 10  1.375292  1.651587 -0.983844 -0.925686 -0.864490  0.775509  0.468151
# 11 -0.994411 -1.374810 -0.192460 -0.096610 -0.047943 -0.285663  0.236894
# 12  0.826931 -0.629176  0.515620  0.575226  0.437572  1.026624  0.236894
# 13 -1.297968 -0.234429  0.557272  0.389399  0.393434  0.775509  0.908155
# 14  0.151272 -0.629176 -2.275049 -2.269360 -2.254827 -0.860380  0.908155
# 15  0.689841  0.642788 -1.289290 -1.497462 -1.658968 -1.779464  0.468151
# 16  2.609104  0.511205 -1.122683 -1.297340 -1.327935  1.026624  2.090290
# 17  0.464621  0.028736  0.668344  0.646698  0.702398 -0.860380 -1.075339
# 18  0.033766  2.221778  0.904370  0.903998  0.812742 -0.285663 -0.786909
# 19  0.376492 -1.418671 -1.053264 -1.140102 -1.173453 -0.860380  0.691654
# 20  0.905268 -1.155506 -0.747817 -0.854214 -0.754146  0.485908  0.468151
# 21 -0.994411  1.256840 -0.150808  0.017745  0.128608 -1.779464  0.236894
# 22 -1.415474 -0.629176  0.987674  0.875409  0.989293  0.141896 -0.252670
# 23  0.219817  0.204180  1.667986  1.604423  1.607220 -0.860380 -1.075339
# 24  0.063143 -1.067784 -1.303174 -1.197279 -1.151385  1.026624  2.090290
# 25 -0.906281  0.423484 -0.858889 -0.568326 -0.533457  1.248961  1.521585
# 26  0.591919  2.134056  0.335129  0.317927  0.172746 -0.860380  0.236894
# 27  0.738802 -0.058985  0.585040  0.260750  0.283090 -0.860380 -1.381549
# 28  0.307947  0.598927  2.153924  2.319144  2.379630  0.485908 -2.064651
#
#           SV         E
# 0   1.533110 -0.347912
# 1   0.311785 -0.540600
# 2  -0.664287 -1.326658
# 3  -0.820779  0.650976
# 4  -1.149085 -0.540600
# 5   0.677037  0.083252
# 6   0.052064 -1.589036
# 7   1.908829  0.237939
# 8  -0.365236  0.383630
# 9   0.311785  1.553586
# 10 -0.512525 -0.641710
# 11  0.436628  0.083252
# 12  0.311785  0.161804
# 13 -2.497448  1.809519
# 14  2.085792  0.311926
# 15  1.333214  1.668393
# 16  0.677037  1.203392
# 17 -0.365236  1.430320
# 18 -1.149085 -0.167309
# 19  0.905981 -0.347912
# 20 -0.222185 -0.167309
# 21 -1.149085 -1.589036
# 22  0.183651 -0.167309
# 23 -1.149085  1.472349
# 24  0.558331 -1.871420
# 25 -0.222185 -1.455430
# 26  0.183651 -0.540600
# 27 -0.222185  0.002283
# 28 -0.982277  0.237939

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#      VIF values Features
# 0      6.915528        R
# 1     12.146904       AB
# 2      1.720240        H
# 3      3.572912       2B
# 4      3.289336       3B
# 5      7.982448       HR
# 6      3.377426       BB
# 7      2.820351       SO
# 8      1.804178       SB
# 9    203.816755       RA
# 10  2001.907470       ER
# 11  1523.669259      ERA
# 12     2.629975       CG
# 13     3.207922      SHO
# 14     5.367203       SV
# 15     1.806930        E

# %% [markdown]
# VIF = 1: Indicates no multicollinearity,
# VIF >= 5: Indicates high multicollinearity,
# VIF > 1 and VIF < 5: Suggests moderate multicollinearity

# %%
# removing the ER
x = x.drop("ER", axis=1)

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values Features
# 0     4.748170        R
# 1     3.458580       AB
# 2     1.648048        H
# 3     3.330980       2B
# 4     3.114272       3B
# 5     5.332146       HR
# 6     3.342196       BB
# 7     2.792994       SO
# 8     1.736267       SB
# 9   142.989879       RA
# 10  138.143025      ERA
# 11    2.381165       CG
# 12    3.148206      SHO
# 13    2.481043       SV
# 14    1.799371        E

# %%
# removing the ER
x = x.drop("RA", axis=1)

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values Features
# 0     4.454179        R
# 1     2.485794       AB
# 2     1.414955        H
# 3     3.279943       2B
# 4     3.101677       3B
# 5     5.217480       HR
# 6     2.748650       BB
# 7     2.255441       SO
# 8     1.576255       SB
# 9     4.415210      ERA
# 10    2.347105       CG
# 11    2.871292      SHO
# 12    2.352692       SV
# 13    1.597301        E

# %% [markdown]
# # Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.98257636589529 on random state 47

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: -0.09305926247927898
# R2 score on training data: 94.18107864612774
# Mean Absolute Error: 11.041168863506762
# Mean Squared Error: 147.4415494055383
# Root Mean Squared Error: 12.142551190155151

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.37625304777594726
# R2 score on training data: 91.26493333333335
# Mean Absolute Error: 7.377777777777776
# Mean Squared Error: 84.13653333333335
# Root Mean Squared Error: 9.172596869662012

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.13242174629324532
# R2 score on training data: 68.07272727272726
# Mean Absolute Error: 8.822222222222223
# Mean Squared Error: 117.0266666666667
# Root Mean Squared Error: 10.817886423265254

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: 0.4299431205034444
# R2 score on training data: 99.99999757307519
# Mean Absolute Error: 7.434245959483395
# Mean Squared Error: 76.89433907875761
# Root Mean Squared Error: 8.76894173083375

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.6296723813199139
# R2 score on training data: 86.54898579936712
# Mean Absolute Error: 5.678912347031978
# Mean Squared Error: 49.953081008624956
# Root Mean Squared Error: 7.067749359493796

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.471330890611959
# R2 score on training data: 93.40932054901356
# Mean Absolute Error: 7.487633935244442
# Mean Squared Error: 71.31158875523131
# Root Mean Squared Error: 8.44461892303207

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: -0.07534667694978348
# R2 score on training data: 23.73580390172251
# Mean Absolute Error: 10.395581225424117
# Mean Squared Error: 145.05231842411524
# Root Mean Squared Error: 12.043766787185612

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.4374745469522243
# R2 score on training data: 100.0
# Mean Absolute Error: 7.243333333333331
# Mean Squared Error: 75.87843333333329
# Root Mean Squared Error: 8.710822770171214

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.51072627 -1.48304817  0.66847175  0.67726992  0.62219759]
# 0.19912346955626586
# Difference between R2 score and CVS is: -29.218273203554485

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [ 0.25521045 -5.522225    0.35162802  0.34220361  0.83551091]
# -0.7475344018260166
# Difference between R2 score and CVS is: 112.37874496019637

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-0.15268182 -2.62263158  0.31626934  0.21147541  0.57228774]
# -0.33505618161461825
# Difference between R2 score and CVS is: 46.747792790786356

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-1.46821700e-03 -8.52056242e+00  4.34467041e-01  4.79483871e-01
#   8.07186328e-01]
# -1.3601786804331388
# Difference between R2 score and CVS is: 179.01218009365834

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ 0.75000939 -0.59947358  0.78946149  0.78168031  0.880785  ]
# 0.5204925220011734
# Difference between R2 score and CVS is: 10.917985931874053

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [ 0.39729512 -1.33637327  0.70276417  0.89976462  0.74295456]
# 0.2812810376515036
# Difference between R2 score and CVS is: 19.00498529604554

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [-0.10611725 -1.26495176 -0.02447908 -0.4924816   0.1252961 ]
# -0.3525467169963143
# Difference between R2 score and CVS is: 27.72000400465308

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [ 0.10092045 -4.57793158  0.52317307  0.36252525  0.8616138 ]
# -0.5459398031335121
# Difference between R2 score and CVS is: 98.34143500857364

# %% [markdown]
# We will take Lass as it has least difference

# %% [markdown]
# # HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler  # If feature scaling is desired

# Optionally, scale features:
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

param = {
    'alpha': [0.01, 0.1, 1.0, 10.0],
    'fit_intercept': [True, False],
    # 'normalize': [True, False],  # Removed
    'precompute': [True, False],
    'selection': ['cyclic', 'random']
}

gscv = GridSearchCV(Lasso(), param, cv=5)

# Use scaled data if applicable:
gscv.fit(x_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.0],
#                          'fit_intercept': [True, False],
#                          'precompute': [True, False],
#                          'selection': ['cyclic', 'random']})

# %%
 gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'precompute': True,
#  'selection': 'random'}

# %%
Model = Lasso(alpha=1.0,
             fit_intercept=True,
             precompute=True,
             selection='random')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.6294709145952405
# Mean Absolute Error: 5.680308305532374
# Mean Squared Error: 49.98025663126422
# Root Mean Squared Error: 7.069671607031278

# %%
import pickle
filename='Baseball Case Study winners.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Baseball Case Study winners.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 62.94709145952405

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])   
conclusion
# Out:
#                     0          1          2          3          4          5  \
# Predicted   91.381365  72.112043  73.651798  86.418727  80.456293  72.884549
# original   100.000000  76.000000  74.000000  86.000000  76.000000  64.000000
#
#                    6          7          8
# Predicted  82.442745  85.039094  88.009751
# original   95.000000  87.000000  98.000000
